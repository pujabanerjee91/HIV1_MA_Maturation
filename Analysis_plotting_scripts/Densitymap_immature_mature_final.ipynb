# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm


s=8
m=10
l=12

plt.rc('legend', fontsize=s)
plt.rc('xtick', labelsize=s)
plt.rc('ytick', labelsize=s)

fig = plt.figure(figsize=(6.0,10.0))

ax1 = fig.add_subplot(421)   

data = np.loadtxt(r'immature/DOPS_densitymap.dat')

origin = 'lower'

X=data[:,0]
Y=data[:,1]
Z=data[:,2]
Xs=X.reshape((601,601))
Ys=Y.reshape((601,601))
Zs=Z.reshape((601,601))

cp = ax1.contourf(Xs, Ys, Zs, levels=7, vmin=0.0, vmax=70.0, cmap=plt.cm.rainbow)
m = plt.cm.ScalarMappable(cmap=cm.rainbow)
m.set_array(Z)
m.set_clim(0., 70.)
plt.colorbar(m, boundaries=np.linspace(0, 70, 8))

 
plt.xlim(3, 12)
plt.ylim(3, 12)
plt.yticks(np.arange(3, 12, 2))
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

ax1.set_title('Immature MA \n PS', y=1.0)


####################################

ax2 = fig.add_subplot(422)   

data = np.loadtxt(r'mature/DOPS_densitymap.dat')

origin = 'lower'

X=data[:,0]
Y=data[:,1]
Z=data[:,2]
Xs=X.reshape((601,601))
Ys=Y.reshape((601,601))
Zs=Z.reshape((601,601))


cp = ax2.contourf(Xs, Ys, Zs, levels=7, vmin=0.0, vmax=70.0, cmap=plt.cm.rainbow)
m = plt.cm.ScalarMappable(cmap=cm.rainbow)
m.set_array(Z)
m.set_clim(0., 70.)
cbar=plt.colorbar(m, boundaries=np.linspace(0, 70, 8))
cbar.set_label('number density(nm$^{-3}$)', labelpad=15, rotation=270)



ax2.set_title('Mature MA \n PS', y=1.0)
plt.xlim(3, 12)
plt.ylim(3, 12)
plt.yticks(np.arange(3, 12, 2))
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

#####################################

ax3 = fig.add_subplot(423)   

data = np.loadtxt(r'immature/lowerCHL1_densitymap.dat')

origin = 'lower'

X=data[:,0]
Y=data[:,1]
Z=data[:,2]
Xs=X.reshape((601,601))
Ys=Y.reshape((601,601))
Zs=Z.reshape((601,601))


cp = ax3.contourf(Xs, Ys, Zs, levels=5, vmin=0.0, vmax=50.0, cmap=plt.cm.rainbow)
m = plt.cm.ScalarMappable(cmap=cm.rainbow)
m.set_array(Z)
m.set_clim(0., 50.)
plt.colorbar(m, boundaries=np.linspace(0, 50, 6))


ax3.set_title('Chol:inner', y=1.0)
plt.xlim(3, 12)
plt.ylim(3, 12)
plt.yticks(np.arange(3, 12, 2))

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

##############################################

ax4 = fig.add_subplot(424)   

data = np.loadtxt(r'mature/lower_CHL1_densitymap.dat')

origin = 'lower'

X=data[:,0]
Y=data[:,1]
Z=data[:,2]
Xs=X.reshape((601,601))
Ys=Y.reshape((601,601))
Zs=Z.reshape((601,601))


cp = ax4.contourf(Xs, Ys, Zs, levels=5, vmin=0.0, vmax=50.0, cmap=plt.cm.rainbow)
m = plt.cm.ScalarMappable(cmap=cm.rainbow)
m.set_array(Z)
m.set_clim(0., 50.)
cbar=plt.colorbar(m, boundaries=np.linspace(0, 50, 6))
cbar.set_label('number density(nm$^{-3}$)', labelpad=15, rotation=270)


ax4.set_title('Chol:inner', y=1.0)
plt.xlim(3, 12)
plt.ylim(3, 12)
plt.yticks(np.arange(3, 12, 2))

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

########################################

ax5 = fig.add_subplot(425)   

data = np.loadtxt(r'immature/upperCHL1_densitymap.dat')

origin = 'lower'

X=data[:,0]
Y=data[:,1]
Z=data[:,2]
Xs=X.reshape((601,601))
Ys=Y.reshape((601,601))
Zs=Z.reshape((601,601))



cp = ax5.contourf(Xs, Ys, Zs, cmap=plt.cm.rainbow, origin=origin)
plt.colorbar(cp)

ax5.set_title('Chol:outer', y=1.0)
plt.xlim(3, 12)
plt.ylim(3, 12)
plt.yticks(np.arange(3, 12, 2))

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

##############################################

ax6 = fig.add_subplot(426)   

data = np.loadtxt(r'mature/upper_CHL1_densitymap.dat')

origin = 'lower'

X=data[:,0]
Y=data[:,1]
Z=data[:,2]
Xs=X.reshape((601,601))
Ys=Y.reshape((601,601))
Zs=Z.reshape((601,601))



cp = ax6.contourf(Xs, Ys, Zs, cmap=plt.cm.rainbow, origin=origin)
cbar=plt.colorbar(cp)
cbar.set_label('number density(nm$^{-3}$)', labelpad=15, rotation=270)

ax6.set_title('Chol:outer', y=1.0)
plt.xlim(3, 12)
plt.ylim(3, 12)
plt.yticks(np.arange(3, 12, 2))

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off


##############################################

ax7 = fig.add_subplot(427)   

data = np.loadtxt(r'immature/LSM_densitymap.dat')

origin = 'lower'

X=data[:,0]
Y=data[:,1]
Z=data[:,2]
Xs=X.reshape((601,601))
Ys=Y.reshape((601,601))
Zs=Z.reshape((601,601))


cp = ax7.contourf(Xs, Ys, Zs, levels=6, vmin=0.0, vmax=120.0, cmap=plt.cm.rainbow)
m = plt.cm.ScalarMappable(cmap=cm.rainbow)
m.set_array(Z)
m.set_clim(0., 120.)
plt.colorbar(m, boundaries=np.linspace(0, 120, 7))



ax7.set_title('SM', y=1.0)
plt.xlim(3, 12)
plt.ylim(3, 12)
#plt.clim(-15,72)
plt.yticks(np.arange(3, 12, 2))
plt.xticks(np.arange(3, 12, 2))


##############################################

ax8 = fig.add_subplot(428)   

data = np.loadtxt(r'mature/LSM_densitymap.dat')

origin = 'lower'

X=data[:,0]
Y=data[:,1]
Z=data[:,2]
Xs=X.reshape((601,601))
Ys=Y.reshape((601,601))
Zs=Z.reshape((601,601))


cp = ax8.contourf(Xs, Ys, Zs, levels=6, vmin=0.0, vmax=120.0, cmap=plt.cm.rainbow)
m = plt.cm.ScalarMappable(cmap=cm.rainbow)
m.set_array(Z)
m.set_clim(0., 120.)
cbar=plt.colorbar(m, boundaries=np.linspace(0, 120, 7))
cbar.set_label('number density(nm$^{-3}$)', labelpad=15, rotation=270)





ax8.set_title('SM', y=1.0)
plt.xlim(3, 12)
plt.ylim(3, 12)
plt.yticks(np.arange(3, 12, 2))
plt.xticks(np.arange(3, 12, 2))
fig.text(0.5, 0.09, r"x(nm)", ha='center')
fig.text(0.05, 0.5, r"y(nm)", va='center', rotation='vertical')
plt.savefig('lipiddensity_MA6virions_compare.png', dpi=300)
plt.show()
